# %% [markdown]
# # **PREREQUISITE DATA SCIENCE MINI BOOTCAMP 2023**
# ---
# Nama:
# Pande Kadek Nathan Prabhaswara Sudiara Putra
#
# NIM:
# 235150207111051

# %% [markdown]
# Setelah mengikuti workshop Introduction to Python and Pandas pada tanggal 23 Oktober lalu, tentunya kalian sudah mulai paham dengan apa yang akan dilakukan oleh Data Scientist. Sekarang saatnya mengukur kemampuan kalian dari apa yang telah kalian dapatkan pada workshop sebelumnya.
#
# **DEADLINE: SENIN, 30 OKTOBER 2023 PUKUL 12.00 SIANG**
#
# ### **Silakan copy colab ini ke drive masing-masing**

# %% [markdown]
# ## 1. Buatlah program BMI menggunakan bahasa Python
#
# - BMI (Body Mass Index) merupakan perhitungan berat badan ideal seseorang dimana rumus dari BMI adalah sebagai berikut:
#
#     ![rumus-bmi-cara-menghitung-berat-badan-ideal.jpeg](https://openaccesspub.org/article/926/images/image1.jpg)
#
# - Buatlah program yang menerima 2 input (berat badan & tinggi badan) kemudian keluarkan hasil BMI nya dan keterangan dari BMI tersebut

# %%
#Tulis Program Disini
weight = float(input("Berat Badan : "))
height = float(input("Tinggi Badan: "))

BMI = weight/height**2

if (BMI >= 30.0):
    print("Very overweight")
elif (BMI <30.0 and BMI >= 25.0):
    print("overweight")
elif (BMI <25.0 and BMI >= 18.5):
    print("normal")
else:
    print("underweight")
# Out:
# underweight

# %% [markdown]
# ### 2. Buatlah Piramida Bintang menggunakan bahasa Python
#
# - Buatlah program yang dapat mencetak output seperti dibawah ini menggunakan looping python
#
#     ![piramida-bintang.png](https://i.ibb.co/BtqjZrL/piramida-bintang.png)

# %%
#Tulis Program Disini
row = 5
count = 0

for i in range(0, row):
    count += 2
    for j in range(row - 1, i, -1):
        print(" ", end="")
    
    for k in range(1, count):
        print("*", end="")

    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********
